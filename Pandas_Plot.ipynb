# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
df_census = pd.read_csv('census.csv')
df_census.head(3)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# 1          7.242091         -2.915927         -3.012349          2.265971
# 2         14.832960         17.647293         21.845705         19.243287
#
#    RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  \
# ...

# %%
# plot histogram to all numeric values
df_census.hist(figsize=(20,20)); # suppresses output without suppressing graph

# %%
df_census['RDOMESTICMIG2014'].hist(); # plot on a specific column

# %%
# specify kind of plot as parameter
df_census['RNETMIG2012'].plot(kind='box')

# %%
# specify kind of plot as parameter
df_census['RDOMESTICMIG2014'].plot(kind='line')

# %%
# for bar charts, you need counts for each value
# eg. df_census['string'].value_counts().plot(kind='box',figsize=(10,10))
df_census['RDOMESTICMIG2014'].plot(kind='bar')

# %%
df_census['SUMLEV'].plot(kind='pie', figsize=(8,8))
