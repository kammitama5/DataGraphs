# %%
import pandas as pd
import numpy as np

df = pd.read_csv('cancer.csv')
df.head()
# Out:
#      842302  M  17.99  10.38   122.8    1001   0.1184   0.2776  0.3001  \
# 0    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 1  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 2  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 3  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
# 4    843786  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.1578
#
#     0.1471   ...     25.38  17.33   184.6    2019  0.1622  0.6656  0.7119  \
# 0  0.07017   ...     24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 1  0.12790   ...     23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 2  0.10520   ...     14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 3  0.10430   ...     22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
# 4  0.08089   ...     15.47  23.75  103.40   741.6  0.1791  0.5249  0.5355
#
#    0.2654  0.4601   0.1189
# 0  0.1860  0.2750  0.08902
# 1  0.2430  0.3613  0.08758
# ...

# %%
df.columns = ['id', 'diagnosis','radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_SE', 'texture_SE', 'perimeter_SE', 'area_SE', 'smoothness_SE','compactness_SE', 'concavity_SE', 'concave_points_SE', 'symmetry_SE', 'fractal_dimension_SE', 'radius_max', 'texture_max', 'perimeter_max', 'area_max', 'smoothness_max', 'compactness_max', 'concavity_max', 'concave_points_max', 'symmetry_max', 'fractal_dimension_max']

# %%
df.head(3)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842517         M        20.57         17.77          132.90     1326.0
# 1  84300903         M        19.69         21.25          130.00     1203.0
# 2  84348301         M        11.42         20.38           77.58      386.1
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.08474           0.07864          0.0869              0.07017
# 1          0.10960           0.15990          0.1974              0.12790
# 2          0.14250           0.28390          0.2414              0.10520
#
#            ...            radius_max  texture_max  perimeter_max  area_max  \
# 0          ...                 24.99        23.41         158.80    1956.0
# 1          ...                 23.57        25.53         152.50    1709.0
# 2          ...                 14.91        26.50          98.87     567.7
#
# ...

# %%
# replace all non-null values with mean value
mean = df.mean()
df.fillna(mean, inplace=True)
# confirm the correction with info()
df.info()
df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 32 columns):
# id                        568 non-null int64
# diagnosis                 568 non-null object
# radius_mean               568 non-null float64
# texture_mean              568 non-null float64
# perimeter_mean            568 non-null float64
# area_mean                 568 non-null float64
# smoothness_mean           568 non-null float64
# compactness_mean          568 non-null float64
# concavity_mean            568 non-null float64
# concave_points_mean       568 non-null float64
# symmetry_mean             568 non-null float64
# fractal_dimension_mean    568 non-null float64
# radius_SE                 568 non-null float64
# texture_SE                568 non-null float64
# perimeter_SE              568 non-null float64
# area_SE                   568 non-null float64
# smoothness_SE             568 non-null float64
# compactness_SE            568 non-null float64
# ...

# %%
# check for duplicates
sum(df.duplicated()) # 0
# Out:
# 0

# %%
# drop duplicates
df.drop_duplicates(inplace=True)
# shouldn't do anything

# %%
# confirm correction by rechecking for duplicates in the data
sum(df.duplicated())
# Out:
# 0

# %%
# remove "_mean" from column names
new_labels = []
for col in df.columns:
    if '_mean' in col:
        new_labels.append(col[:-5]) # append without "_mean", which is last five chars
    else:
        new_labels.append(col)
new_labels # no column name has "_mean" in it
# Out:
# ['id',
#  'diagnosis',
#  'radius',
#  'texture',
#  'perimeter',
#  'area',
#  'smoothness',
#  'compactness',
#  'concavity',
#  'concave_points',
#  'symmetry',
#  'fractal_dimension',
#  'radius_SE',
#  'texture_SE',
#  'perimeter_SE',
#  'area_SE',
#  'smoothness_SE',
#  'compactness_SE',
#  'concavity_SE',
#  'concave_points_SE',
#  'symmetry_SE',
#  'fractal_dimension_SE',
#  'radius_max',
#  'texture_max',
#  'perimeter_max',
#  'area_max',
#  'smoothness_max',
#  'compactness_max',
#  'concavity_max',
#  'concave_points_max',
#  'symmetry_max',
#  'fractal_dimension_max']

# %%
# assign new labels to columns in dataframe
df.columns = new_labels
# check that changes have taken place
df.head(3)
# Out:
#          id diagnosis  radius  texture  perimeter    area  smoothness  \
# 0    842517         M   20.57    17.77     132.90  1326.0     0.08474
# 1  84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 2  84348301         M   11.42    20.38      77.58   386.1     0.14250
#
#    compactness  concavity  concave_points          ...            radius_max  \
# 0      0.07864     0.0869         0.07017          ...                 24.99
# 1      0.15990     0.1974         0.12790          ...                 23.57
# 2      0.28390     0.2414         0.10520          ...                 14.91
#
#    texture_max  perimeter_max  area_max  smoothness_max  compactness_max  \
# 0        23.41         158.80    1956.0          0.1238           0.1866
# 1        25.53         152.50    1709.0          0.1444           0.4245
# 2        26.50          98.87     567.7          0.2098           0.8663
#
#    concavity_max  concave_points_max  symmetry_max  fractal_dimension_max
# ...

# %%
# save this for later
df.to_csv('cancer_data_edited.csv')

# %%
# plotting
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
